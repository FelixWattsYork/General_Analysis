# %%
from pyrokinetics import Pyro, PyroScan
import os
from pathlib import Path
import numpy as np

# %%
# Replace with path to your Gyrokinetic Simulations
GYRO_DIR  = Path("/mnt/data/Gyrokinetic_Simulations/")

# %%
cases = ["M1_A1","S1"]
projects = ["nl_exb_scan"]

# %%
project_dict ={}
for project in projects:
    case_dict = {}
    for case in cases:
        json_path = Path(GYRO_DIR / Path(f"GENE/Runs/{project}/{case}/pyroscan.json"))
        net_cdf_path = Path(GYRO_DIR / Path(f"GENE/Runs/{project}/{case}/pyroscan.nc"))
        gene_pyoscan = PyroScan(pyroscan_json=json_path, load_base_pyro=True)
        gene_pyoscan.load_gk_output(netcdf_file=net_cdf_path)
        case_dict[case] = gene_pyoscan
        project_dict[project] = case_dict
# Out:
# /home/Felix/Documents/Physics_Work/Project_Codes/EPS_2026_Analysis/.venv/lib/python3.14/site-packages/pyrokinetics/normalisation.py:941: UserWarning: Reference values 'tref_electron', 'nref_electron', 'bref_B0', 'lref_minor_radius', 'lref_major_radius' are already set for 'pyroscan_base0000'.
#   warnings.warn(
# /home/Felix/Documents/Physics_Work/Project_Codes/EPS_2026_Analysis/.venv/lib/python3.14/site-packages/pyrokinetics/pyro.py:1785: UserWarning: Explicitly set value of beta (0.09 beta_ref_ee_B0_pyroscan_base0001) is inconsistent with value from physical reference values (0.09617910133883377 beta_ref_ee_B0_pyroscan_base0001)
#   warnings.warn(
# /home/Felix/Documents/Physics_Work/Project_Codes/EPS_2026_Analysis/.venv/lib/python3.14/site-packages/pyrokinetics/normalisation.py:941: UserWarning: Reference values 'tref_electron', 'nref_electron', 'bref_B0', 'lref_minor_radius', 'lref_major_radius' are already set for 'pyroscan_base0001'.
#   warnings.warn(

# %%
tglf_versions = ["tglf_default","tglf_v5_nb6","tglf_v5_nb6_negwm","tglf_v5_nm10","tglf_v5_nm10_negwm"]
tglf_sat_rules = ["sat1","sat2","sat3"]
tglf_grid_models = [1,4]

name_dict = {
    "tglf_default":"Default",
    "tglf_v5_nb6":"V5_NB6",
    "tglf_v5_nb6_negwm":"V5_NB6_EMWS",
    "tglf_v5_nm10":"V5_NM10",
    "tglf_v5_nm10_negwm":"V5_NM10_EMWS",
}

tglf_project_dict ={}
for project in projects:
    case_dict = {}
    for case in cases:
        version_dict = {}
        for version in tglf_versions:
            sat_rules = {}
            for sat_rule in tglf_sat_rules:
                grid_models = {}
                for grid_model in tglf_grid_models:
                    json_path = Path(GYRO_DIR / Path(f"TGLF/Runs/{project}/{case}/{version}/{sat_rule}_kygrid{grid_model}/pyroscan.json"))
                    net_cdf_path = Path(GYRO_DIR / Path(f"TGLF/Runs/{project}/{case}/{version}/{sat_rule}_kygrid{grid_model}/pyroscan.nc"))
                    tglf_pyoscan = PyroScan(pyroscan_json=json_path, load_base_pyro=True)
                    tglf_pyoscan.load_gk_output(netcdf_file=net_cdf_path)
                    grid_models[grid_model] = tglf_pyoscan
                sat_rules[sat_rule] = grid_models
            version_dict[version] = sat_rules
        case_dict[case] = version_dict
    tglf_project_dict[project] = case_dict
# Out:
# Error loading pyroscan for nl_exb_scan/M1_A1/tglf_v5_nb6/sat1_kygrid1: [Errno 2] No such file or directory: '/mnt/data/Gyrokinetic_Simulations/TGLF/Runs/nl_exb_scan/M1_A1/tglf_v5_nb6/sat1_kygrid1/pyroscan.json'
# Error loading pyroscan for nl_exb_scan/M1_A1/tglf_v5_nb6/sat1_kygrid4: [Errno 2] No such file or directory: '/mnt/data/Gyrokinetic_Simulations/TGLF/Runs/nl_exb_scan/M1_A1/tglf_v5_nb6/sat1_kygrid4/pyroscan.json'
# Error loading pyroscan for nl_exb_scan/M1_A1/tglf_v5_nb6/sat2_kygrid4: [Errno 2] No such file or directory: '/mnt/data/Gyrokinetic_Simulations/TGLF/Runs/nl_exb_scan/M1_A1/tglf_v5_nb6/sat2_kygrid4/pyroscan.json'
# Error loading pyroscan for nl_exb_scan/M1_A1/tglf_v5_nb6/sat3_kygrid4: [Errno 2] No such file or directory: '/mnt/data/Gyrokinetic_Simulations/TGLF/Runs/nl_exb_scan/M1_A1/tglf_v5_nb6/sat3_kygrid4/pyroscan.json'
# Error loading pyroscan for nl_exb_scan/M1_A1/tglf_v5_nb6_negwm/sat1_kygrid1: [Errno 2] No such file or directory: '/mnt/data/Gyrokinetic_Simulations/TGLF/Runs/nl_exb_scan/M1_A1/tglf_v5_nb6_negwm/sat1_kygrid1/pyroscan.json'
# Error loading pyroscan for nl_exb_scan/M1_A1/tglf_v5_nb6_negwm/sat1_kygrid4: [Errno 2] No such file or directory: '/mnt/data/Gyrokinetic_Simulations/TGLF/Runs/nl_exb_scan/M1_A1/tglf_v5_nb6_negwm/sat1_kygrid4/pyroscan.json'
# Error loading pyroscan for nl_exb_scan/M1_A1/tglf_v5_nb6_negwm/sat2_kygrid4: [Errno 2] No such file or directory: '/mnt/data/Gyrokinetic_Simulations/TGLF/Runs/nl_exb_scan/M1_A1/tglf_v5_nb6_negwm/sat2_kygrid4/pyroscan.json'
# Error loading pyroscan for nl_exb_scan/M1_A1/tglf_v5_nb6_negwm/sat3_kygrid4: [Errno 2] No such file or directory: '/mnt/data/Gyrokinetic_Simulations/TGLF/Runs/nl_exb_scan/M1_A1/tglf_v5_nb6_negwm/sat3_kygrid4/pyroscan.json'
# Error loading pyroscan for nl_exb_scan/M1_A1/tglf_v5_nm10/sat1_kygrid1: [Errno 2] No such file or directory: '/mnt/data/Gyrokinetic_Simulations/TGLF/Runs/nl_exb_scan/M1_A1/tglf_v5_nm10/sat1_kygrid1/pyroscan.json'
# Error loading pyroscan for nl_exb_scan/M1_A1/tglf_v5_nm10/sat1_kygrid4: [Errno 2] No such file or directory: '/mnt/data/Gyrokinetic_Simulations/TGLF/Runs/nl_exb_scan/M1_A1/tglf_v5_nm10/sat1_kygrid4/pyroscan.json'
# Error loading pyroscan for nl_exb_scan/M1_A1/tglf_v5_nm10/sat2_kygrid4: [Errno 2] No such file or directory: '/mnt/data/Gyrokinetic_Simulations/TGLF/Runs/nl_exb_scan/M1_A1/tglf_v5_nm10/sat2_kygrid4/pyroscan.json'
# Error loading pyroscan for nl_exb_scan/M1_A1/tglf_v5_nm10/sat3_kygrid4: [Errno 2] No such file or directory: '/mnt/data/Gyrokinetic_Simulations/TGLF/Runs/nl_exb_scan/M1_A1/tglf_v5_nm10/sat3_kygrid4/pyroscan.json'
# Error loading pyroscan for nl_exb_scan/M1_A1/tglf_v5_nm10_negwm/sat1_kygrid1: [Errno 2] No such file or directory: '/mnt/data/Gyrokinetic_Simulations/TGLF/Runs/nl_exb_scan/M1_A1/tglf_v5_nm10_negwm/sat1_kygrid1/pyroscan.json'
# Error loading pyroscan for nl_exb_scan/M1_A1/tglf_v5_nm10_negwm/sat1_kygrid4: [Errno 2] No such file or directory: '/mnt/data/Gyrokinetic_Simulations/TGLF/Runs/nl_exb_scan/M1_A1/tglf_v5_nm10_negwm/sat1_kygrid4/pyroscan.json'
# Error loading pyroscan for nl_exb_scan/M1_A1/tglf_v5_nm10_negwm/sat2_kygrid4: [Errno 2] No such file or directory: '/mnt/data/Gyrokinetic_Simulations/TGLF/Runs/nl_exb_scan/M1_A1/tglf_v5_nm10_negwm/sat2_kygrid4/pyroscan.json'
# Error loading pyroscan for nl_exb_scan/M1_A1/tglf_v5_nm10_negwm/sat3_kygrid4: [Errno 2] No such file or directory: '/mnt/data/Gyrokinetic_Simulations/TGLF/Runs/nl_exb_scan/M1_A1/tglf_v5_nm10_negwm/sat3_kygrid4/pyroscan.json'
# Error loading pyroscan for nl_exb_scan/S1/tglf_v5_nb6/sat1_kygrid1: [Errno 2] No such file or directory: '/mnt/data/Gyrokinetic_Simulations/TGLF/Runs/nl_exb_scan/S1/tglf_v5_nb6/sat1_kygrid1/pyroscan.json'
# Error loading pyroscan for nl_exb_scan/S1/tglf_v5_nb6/sat1_kygrid4: [Errno 2] No such file or directory: '/mnt/data/Gyrokinetic_Simulations/TGLF/Runs/nl_exb_scan/S1/tglf_v5_nb6/sat1_kygrid4/pyroscan.json'
# Error loading pyroscan for nl_exb_scan/S1/tglf_v5_nb6/sat2_kygrid4: [Errno 2] No such file or directory: '/mnt/data/Gyrokinetic_Simulations/TGLF/Runs/nl_exb_scan/S1/tglf_v5_nb6/sat2_kygrid4/pyroscan.json'
# Error loading pyroscan for nl_exb_scan/S1/tglf_v5_nb6/sat3_kygrid4: [Errno 2] No such file or directory: '/mnt/data/Gyrokinetic_Simulations/TGLF/Runs/nl_exb_scan/S1/tglf_v5_nb6/sat3_kygrid4/pyroscan.json'
# Error loading pyroscan for nl_exb_scan/S1/tglf_v5_nb6_negwm/sat1_kygrid1: [Errno 2] No such file or directory: '/mnt/data/Gyrokinetic_Simulations/TGLF/Runs/nl_exb_scan/S1/tglf_v5_nb6_negwm/sat1_kygrid1/pyroscan.json'
# Error loading pyroscan for nl_exb_scan/S1/tglf_v5_nb6_negwm/sat1_kygrid4: [Errno 2] No such file or directory: '/mnt/data/Gyrokinetic_Simulations/TGLF/Runs/nl_exb_scan/S1/tglf_v5_nb6_negwm/sat1_kygrid4/pyroscan.json'
# Error loading pyroscan for nl_exb_scan/S1/tglf_v5_nb6_negwm/sat2_kygrid4: [Errno 2] No such file or directory: '/mnt/data/Gyrokinetic_Simulations/TGLF/Runs/nl_exb_scan/S1/tglf_v5_nb6_negwm/sat2_kygrid4/pyroscan.json'
# Error loading pyroscan for nl_exb_scan/S1/tglf_v5_nb6_negwm/sat3_kygrid4: [Errno 2] No such file or directory: '/mnt/data/Gyrokinetic_Simulations/TGLF/Runs/nl_exb_scan/S1/tglf_v5_nb6_negwm/sat3_kygrid4/pyroscan.json'
# Error loading pyroscan for nl_exb_scan/S1/tglf_v5_nm10/sat1_kygrid1: [Errno 2] No such file or directory: '/mnt/data/Gyrokinetic_Simulations/TGLF/Runs/nl_exb_scan/S1/tglf_v5_nm10/sat1_kygrid1/pyroscan.json'
# Error loading pyroscan for nl_exb_scan/S1/tglf_v5_nm10/sat1_kygrid4: [Errno 2] No such file or directory: '/mnt/data/Gyrokinetic_Simulations/TGLF/Runs/nl_exb_scan/S1/tglf_v5_nm10/sat1_kygrid4/pyroscan.json'
# Error loading pyroscan for nl_exb_scan/S1/tglf_v5_nm10/sat2_kygrid4: [Errno 2] No such file or directory: '/mnt/data/Gyrokinetic_Simulations/TGLF/Runs/nl_exb_scan/S1/tglf_v5_nm10/sat2_kygrid4/pyroscan.json'
# Error loading pyroscan for nl_exb_scan/S1/tglf_v5_nm10/sat3_kygrid4: [Errno 2] No such file or directory: '/mnt/data/Gyrokinetic_Simulations/TGLF/Runs/nl_exb_scan/S1/tglf_v5_nm10/sat3_kygrid4/pyroscan.json'
# Error loading pyroscan for nl_exb_scan/S1/tglf_v5_nm10_negwm/sat1_kygrid1: [Errno 2] No such file or directory: '/mnt/data/Gyrokinetic_Simulations/TGLF/Runs/nl_exb_scan/S1/tglf_v5_nm10_negwm/sat1_kygrid1/pyroscan.json'
# Error loading pyroscan for nl_exb_scan/S1/tglf_v5_nm10_negwm/sat1_kygrid4: [Errno 2] No such file or directory: '/mnt/data/Gyrokinetic_Simulations/TGLF/Runs/nl_exb_scan/S1/tglf_v5_nm10_negwm/sat1_kygrid4/pyroscan.json'
# Error loading pyroscan for nl_exb_scan/S1/tglf_v5_nm10_negwm/sat2_kygrid4: [Errno 2] No such file or directory: '/mnt/data/Gyrokinetic_Simulations/TGLF/Runs/nl_exb_scan/S1/tglf_v5_nm10_negwm/sat2_kygrid4/pyroscan.json'
# Error loading pyroscan for nl_exb_scan/S1/tglf_v5_nm10_negwm/sat3_kygrid4: [Errno 2] No such file or directory: '/mnt/data/Gyrokinetic_Simulations/TGLF/Runs/nl_exb_scan/S1/tglf_v5_nm10_negwm/sat3_kygrid4/pyroscan.json'

# %%
from matplotlib import pyplot as plt
# Plot Q scan
project = "nl_exb_scan"
case = "S1"
reference_exb = 3.49


for tglf in tglf_versions:
    for sat_rule in tglf_sat_rules:
        for grid_model in tglf_grid_models:
            try:
                (tglf_project_dict[project][case][tglf][sat_rule][grid_model]
                    .gk_output["heat"].sum(dim="species").sum(dim="field")
                    .plot(label=tglf, marker="o", linestyle="--"))
            except Exception as e:
                print(f"Error plotting {tglf} {sat_rule} grid model {grid_model}: {e}")



project_dict[project][case].gk_output["heat"].sum(dim="species").sum(dim="field").plot(label="GENE", color="black", marker="o")



#plt.axvline(x=reference_q, color='red',alpha=0.3,linestyle = "--")

plt.title("")
plt.xlabel(r"\gamma_{ExB}")
plt.ylabel(r"$(c_s/a) \gamma$")
plt.grid(alpha=0.3, color='grey')
plt.legend()
plt.yscale("log")
plt.xscale("log")
path = f"../Plots/{project}/{case}"
os.makedirs(path, exist_ok=True)
#plt.savefig(f"{path}/Growth Rate vs q — {case}, ky={ky_actual:.3f}.png", dpi=300)
# Out:
# Error plotting tglf_v5_nb6 sat1 grid model 1: 1
# Error plotting tglf_v5_nb6 sat1 grid model 4: 4
# Error plotting tglf_v5_nb6 sat2 grid model 4: 4
# Error plotting tglf_v5_nb6 sat3 grid model 4: 4
# Error plotting tglf_v5_nb6_negwm sat1 grid model 1: 1
# Error plotting tglf_v5_nb6_negwm sat1 grid model 4: 4
# Error plotting tglf_v5_nb6_negwm sat2 grid model 4: 4
# Error plotting tglf_v5_nb6_negwm sat3 grid model 4: 4
# Error plotting tglf_v5_nm10 sat1 grid model 1: 1
# Error plotting tglf_v5_nm10 sat1 grid model 4: 4
# Error plotting tglf_v5_nm10 sat2 grid model 4: 4
# Error plotting tglf_v5_nm10 sat3 grid model 4: 4
# Error plotting tglf_v5_nm10_negwm sat1 grid model 1: 1
# Error plotting tglf_v5_nm10_negwm sat1 grid model 4: 4
# Error plotting tglf_v5_nm10_negwm sat2 grid model 4: 4
# Error plotting tglf_v5_nm10_negwm sat3 grid model 4: 4
# /home/Felix/Documents/Physics_Work/Project_Codes/EPS_2026_Analysis/.venv/lib/python3.14/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from matplotlib import pyplot as plt
# Plot Q scan
project = "nl_exb_scan"
case = "M1_A1"
reference_exb = 3.49

tglf_versions_to_plot = ["tglf_default","tglf_v5_nb6","tglf_v5_nm10"]
tglf_sat_rules_to_plot = ["sat3"]
tglf_grid_models_to_plot = [1]


GENE_context = project_dict[project][case].base_pyro.norms.context

GENE_Heat = project_dict[project][case].gk_output["heat"].sum(dim="species").sum(dim="field").data.to("MW/m^2",GENE_context)
GENE_exb = project_dict[project][case].gk_output["heat"]["gamma_exb"]
plt.plot(GENE_exb,np.abs(GENE_Heat), label="GENE", color="black", marker="o")

for tglf in tglf_versions_to_plot:
    for sat_rule in tglf_sat_rules_to_plot:
        for grid_model in tglf_grid_models_to_plot:
            print(f"Plotting {tglf} {sat_rule} grid model {grid_model}")
            try:
                tglf_heat = tglf_project_dict[project][case][tglf][sat_rule][grid_model].gk_output["heat"].sum(dim="species").sum(dim="field").data.to("MW/m^2",GENE_context)
                tglf_exb = tglf_project_dict[project][case][tglf][sat_rule][grid_model].gk_output["heat"]["gamma_exb"]
                plt.plot(tglf_exb, np.abs(tglf_heat), label=f"{tglf}_{sat_rule}_kx_{grid_model}", marker="o", linestyle="--")
            except Exception as e:
                print(f"Error plotting {tglf} {sat_rule} grid model {grid_model}: {e}")




#plt.axvline(x=reference_q, color='red',alpha=0.3,linestyle = "--")

plt.title("")
plt.ylabel(r"MW/m$^2$")
plt.xlabel(r"$\gamma_{ExB}$")
plt.grid(alpha=0.3, color='grey')
plt.legend()
plt.yscale("log")
#plt.xscale("log")
plt.xlim(GENE_exb[0],5*GENE_exb[-1])
path = f"../Plots/{project}/{case}"
os.makedirs(path, exist_ok=True)
plt.savefig(f"{path}/Heat Flux - ExB shear — {case}.png", dpi=300)
# Out:
# /home/Felix/Documents/Physics_Work/Project_Codes/EPS_2026_Analysis/.venv/lib/python3.14/site-packages/matplotlib/cbook.py:1355: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   return np.asarray(x, float)
# /home/Felix/Documents/Physics_Work/Project_Codes/EPS_2026_Analysis/.venv/lib/python3.14/site-packages/matplotlib/cbook.py:1355: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   return np.asarray(x, float)
# /home/Felix/Documents/Physics_Work/Project_Codes/EPS_2026_Analysis/.venv/lib/python3.14/site-packages/matplotlib/cbook.py:1355: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   return np.asarray(x, float)
# /home/Felix/Documents/Physics_Work/Project_Codes/EPS_2026_Analysis/.venv/lib/python3.14/site-packages/matplotlib/cbook.py:1355: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   return np.asarray(x, float)
# Plotting tglf_default sat3 grid model 1
# Plotting tglf_v5_nb6 sat3 grid model 1
# Plotting tglf_v5_nm10 sat3 grid model 1

# %%
# from matplotlib import pyplot as plt
# # Plot Q scan
# project = "nl_exb_scan"
# case = "M1_A1"
# reference_exb = 3.49

# tglf_versions_to_plot = ["tglf_default","tglf_default_negwm","tglf_v1","tglf_v1_negwm","tglf_v2"]
# tglf_sat_rules_to_plot = ["sat2"]
# tglf_grid_models_to_plot = [4]


# for tglf in tglf_versions_to_plot:
#     for sat_rule in tglf_sat_rules_to_plot:
#         for grid_model in tglf_grid_models_to_plot:
#             tglf_heat = tglf_project_dict[project][case][tglf][sat_rule][grid_model].gk_output["growth_rate"].isel(gamma_exb=10).isel(mode=0).plot(label=f"{tglf}_{sat_rule}_kx_{grid_model}")

# plt.legend()
# plt.xscale("log")

# %%
cases = ["M1_A1_NE","S1"]
projects = ["scan_ky_default"]
gs2_project_dict ={}
for project in projects:
    case_dict = {}
    for case in cases:
        print(f"Project: {project}, Case: {case}")
        json_path = Path(GYRO_DIR / Path(f"GS2/Runs/{project}/{case}/parameter_scan_GS2/pyroscan.json"))
        net_cdf_path = Path(GYRO_DIR / Path(f"GS2/Runs/{project}/{case}/parameter_scan_GS2/pyroscan.nc"))
        try:
            gs2_pyoscan = PyroScan(pyroscan_json=json_path, load_base_pyro=True)
            try:
                gs2_pyoscan.load_gk_output(netcdf_file=net_cdf_path)
                case_dict[case] = gs2_pyoscan
            except Exception as e:
                print(f"Error loading gk output for {project}/{case}: {e}")
                try:
                    gs2_pyoscan.load_gk_output()
                    gs2_pyoscan.gk_output.to_netcdf(net_cdf_path)
                    case_dict[case] = gs2_pyoscan
                except Exception as e:
                    print(f"Error loading gk output without netcdf for {project}/{case}: {e}")
        except Exception as e:
            print(f"Error loading pyroscan for {project}/{case}: {e}")
            continue
    gs2_project_dict[project] = case_dict
# Out:
# Project: scan_ky_default, Case: M1_A1_NE
# /home/Felix/Documents/Physics_Work/Project_Codes/EPS_2026_Analysis/.venv/lib/python3.14/site-packages/pyrokinetics/normalisation.py:941: UserWarning: Reference values 'tref_electron', 'nref_electron', 'bref_B0', 'lref_minor_radius', 'lref_major_radius' are already set for 'pyroscan_base0030'.
#   warnings.warn(
# Project: scan_ky_default, Case: S1
# /home/Felix/Documents/Physics_Work/Project_Codes/EPS_2026_Analysis/.venv/lib/python3.14/site-packages/pyrokinetics/pyro.py:1785: UserWarning: Explicitly set value of beta (0.01 beta_ref_ee_B0_pyroscan_base0031) is inconsistent with value from physical reference values (0.09617910133883378 beta_ref_ee_B0_pyroscan_base0031)
#   warnings.warn(
# /home/Felix/Documents/Physics_Work/Project_Codes/EPS_2026_Analysis/.venv/lib/python3.14/site-packages/pyrokinetics/normalisation.py:941: UserWarning: Reference values 'tref_electron', 'nref_electron', 'bref_B0', 'lref_minor_radius', 'lref_major_radius' are already set for 'pyroscan_base0031'.
#   warnings.warn(

# %%
cases = ["M1_A1_NE"]
projects = ["scan_beta"]
gs2_project_dict ={}
for project in projects:
    case_dict = {}
    for case in cases:
        print(f"Project: {project}, Case: {case}")
        json_path = Path(GYRO_DIR / Path(f"GS2/Runs/{project}/{case}/parameter_scan_GS2/pyroscan.json"))
        net_cdf_path = Path(GYRO_DIR / Path(f"GS2/Runs/{project}/{case}/parameter_scan_GS2/pyroscan.nc"))
        try:
            gs2_pyoscan = PyroScan(pyroscan_json=json_path, load_base_pyro=True)
            try:
                gs2_pyoscan.load_gk_output(netcdf_file=net_cdf_path)
                case_dict[case] = gs2_pyoscan
            except Exception as e:
                print(f"Error loading gk output for {project}/{case}: {e}")
                try:
                    gs2_pyoscan.load_gk_output()
                    gs2_pyoscan.gk_output.to_netcdf(net_cdf_path)
                    case_dict[case] = gs2_pyoscan
                except Exception as e:
                    print(f"Error loading gk output without netcdf for {project}/{case}: {e}")
        except Exception as e:
            print(f"Error loading pyroscan for {project}/{case}: {e}")
            continue
    gs2_project_dict[project] = case_dict
# Out:
# Project: scan_beta, Case: M1_A1_NE
# /home/Felix/Documents/Physics_Work/Project_Codes/EPS_2026_Analysis/.venv/lib/python3.14/site-packages/pyrokinetics/normalisation.py:941: UserWarning: Reference values 'tref_electron', 'nref_electron', 'bref_B0', 'lref_minor_radius', 'lref_major_radius' are already set for 'pyroscan_base0032'.
#   warnings.warn(

# %%
gs2_project_dict["scan_ky_default"]["M1_A1_NE"].gk_output["growth_rate"].plot(label="GS2", color="black")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 gs2_project_dict["scan_ky_default"]["M1_A1_NE"].gk_output["growth_rate"].plot(label="GS2", color="black")
#
# KeyError: 'scan_ky_default'

# %%
gs2_project_dict["scan_beta"]["M1_A1_NE"].gk_output["growth_rate"].sel(beta = 0.04,method="nearest").plot(label="GS2", color="black")

# %%
gs2_project_dict["scan_ky_default"]["M1_A1_NE"].base_pyro.numerics["beta"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 gs2_project_dict["scan_ky_default"]["M1_A1_NE"].base_pyro.numerics["beta"]
#
# KeyError: 'scan_ky_default'

# %%
from matplotlib import pyplot as plt
# Plot Q scan
project = "nl_exb_scan"
case = "M1_A1"
reference_beta = 0.036

tglf_versions_to_plot = ["tglf_default","tglf_default_negwm","tglf_v1","tglf_v1_negwm","tglf_v2"]
tglf_sat_rules_to_plot = ["sat2"]
tglf_grid_models_to_plot = [4]


for tglf in tglf_versions_to_plot:
    for sat_rule in tglf_sat_rules_to_plot:
        for grid_model in tglf_grid_models_to_plot:
            tglf_heat = tglf_project_dict[project][case][tglf][sat_rule][grid_model].gk_output["growth_rate"].isel(gamma_exb=10).isel(mode=0).plot(label=f"{tglf}_{sat_rule}_kx_{grid_model}")

gs2_project_dict["scan_ky_default"]["M1_A1_NE"].gk_output["growth_rate"].plot(label="GS2", color="black")

plt.legend()
plt.xscale("log")
plt.yscale("log")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 17
#      13     for sat_rule in tglf_sat_rules_to_plot:
#      14         for grid_model in tglf_grid_models_to_plot:
#      15             tglf_heat = tglf_project_dict[project][case][tglf][sat_rule][grid_model].gk_output["growth_rate"].isel(gamma_exb=10).isel(mode=0).plot(label=f"{tglf}_{sat_rule}_kx_{grid_model}")
#      16
# ---> 17 gs2_project_dict["scan_ky_default"]["M1_A1_NE"].gk_output["growth_rate"].plot(label="GS2", color="black")
#      18
#      19 plt.legend()
#      20 plt.xscale("log")
#
# KeyError: 'scan_ky_default'

# %%
from matplotlib import pyplot as plt
# Plot Q scan
project = "nl_exb_scan"
case = "M1_A1"
reference_beta = 0.036

tglf_versions_to_plot = ["tglf_default","tglf_default_negwm","tglf_v1","tglf_v1_negwm","tglf_v2"]
tglf_sat_rules_to_plot = ["sat2"]
tglf_grid_models_to_plot = [4]


for tglf in tglf_versions_to_plot:
    for sat_rule in tglf_sat_rules_to_plot:
        for grid_model in tglf_grid_models_to_plot:
            tglf_heat = tglf_project_dict[project][case][tglf][sat_rule][grid_model].gk_output["growth_rate"].isel(gamma_exb=10).isel(mode=0).plot(label=f"{tglf}_{sat_rule}_kx_{grid_model}")

gs2_project_dict["scan_ky_default"]["M1_A1_NE"].gk_output["growth_rate"].plot(label="GS2", color="black")

plt.legend()
plt.xlim(0.01,1)
plt.xscale("log")
plt.yscale("log")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 17
#      13     for sat_rule in tglf_sat_rules_to_plot:
#      14         for grid_model in tglf_grid_models_to_plot:
#      15             tglf_heat = tglf_project_dict[project][case][tglf][sat_rule][grid_model].gk_output["growth_rate"].isel(gamma_exb=10).isel(mode=0).plot(label=f"{tglf}_{sat_rule}_kx_{grid_model}")
#      16
# ---> 17 gs2_project_dict["scan_ky_default"]["M1_A1_NE"].gk_output["growth_rate"].plot(label="GS2", color="black")
#      18
#      19 plt.legend()
#      20 plt.xlim(0.01,1)
#
# KeyError: 'scan_ky_default'

# %%
cases = ["M1_A1","S1"]
projects = ["nl_exb_scan"]

project_dict_full ={}
for project in projects:
    case_dict = {}
    for case in cases:
        json_path = Path(GYRO_DIR / Path(f"GENE/Runs/{project}/{case}/pyroscan.json"))
        net_cdf_path = Path(GYRO_DIR / Path(f"GENE/Runs/{project}/{case}/pyroscan_full.nc"))
        gene_pyoscan = PyroScan(pyroscan_json=json_path, load_base_pyro=True)
        gene_pyoscan.load_gk_output(netcdf_file=net_cdf_path)
        case_dict[case] = gene_pyoscan
    project_dict_full[project] = case_dict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 8
#       4 project_dict_full ={}
#       5 for project in projects:
#       6     case_dict = {}
#       7     for case in cases:
# ----> 8         json_path = Path(GYRO_DIR / Path(f"GENE/Runs/{project}/{case}/pyroscan.json"))
#       9         net_cdf_path = Path(GYRO_DIR / Path(f"GENE/Runs/{project}/{case}/pyroscan_full.nc"))
#      10         gene_pyoscan = PyroScan(pyroscan_json=json_path, load_base_pyro=True)
#      11         gene_pyoscan.load_gk_output(netcdf_file=net_cdf_path)
#
# NameError: name 'Path' is not defined

# %%
project_dict_full["nl_exb_scan"]["S1"].gk_output["heat"].sum(dim="species").sum(dim="field").isel(gamma_exb = 5).plot(label="GENE", color="black")

# %%
def converged_flux(da, t_frac=0.2, time_dim="time", n_blocks=None):
    """
    Converged value + 1-sigma uncertainty of a saturated turbulence time trace.

    da       : 1D xarray.DataArray of Q(t) (already reduced to a single time series)
    t_start  : time after which the trace is saturated (discard transient before this)
    n_blocks : number of blocks for block-averaging. If None, chosen as ~T/(5*tau_c).
    """
    da = da.where((da != 0) & da.notnull(), drop=True)
    time = da[time_dim]
    t_start = time.max().item() - t_frac * (time.max().item() - time.min().item())
    q = da.where(da[time_dim] >= t_start, drop=True)
    t = q[time_dim].values
    y = np.asarray(q.values, dtype=float)
    N = y.size
    mean = y.mean()

    # --- integrated autocorrelation time (in samples) ---
    yc = y - mean
    acf = np.correlate(yc, yc, mode="full")[N - 1:]
    acf /= acf[0]
    first_neg = np.argmax(acf < 0)            # integrate up to first zero crossing
    cutoff = first_neg if first_neg > 0 else N
    tau_int = 1.0 + 2.0 * acf[1:cutoff].sum()  # in samples
    dt = np.median(np.diff(t))
    tau_c = tau_int * dt                       # correlation time in time units
    N_eff = N / max(tau_int, 1.0)

    # --- block (batch-means) standard error ---
    if n_blocks is None:
        n_blocks = max(4, int(N / (5 * max(tau_int, 1.0))))  # >= 5 tau per block
    n_blocks = min(n_blocks, N)
    edges = np.array_split(np.arange(N), n_blocks)
    block_means = np.array([y[idx].mean() for idx in edges])
    sem = block_means.std(ddof=1) / np.sqrt(len(block_means))

    return {
        "mean": mean,
        "sem": sem,            # 1-sigma uncertainty on the mean
        "tau_c": tau_c,        # correlation time (same units as t)
        "N_eff": N_eff,        # effective independent samples
        "n_blocks": len(block_means),
        "rel_err_%": 100 * sem / abs(mean),
    }

# %%
import xarray as xr
from matplotlib import pyplot as plt
# Plot Q scan
project = "nl_exb_scan"
case = "S1"
reference_exb = 3.49
t_start_frac = 0.4   # discard this leading fraction of each GENE trace as transient



tglf_versions_to_plot = ["tglf_default","tglf_v1","tglf_v2"]
tglf_sat_rules_to_plot = ["sat1","sat3"]
tglf_grid_models_to_plot = [4]

marker_map = {"sat1": "o", "sat2": "^", "sat3": "s"}
style_map  = {"sat1": "-", "sat2": "--", "sat3": ":"}

version_labels = [name_dict.get(v, v) for v in tglf_versions_to_plot]
unique_versions = list(dict.fromkeys(version_labels))
color_cycle = plt.rcParams["axes.prop_cycle"].by_key()["color"]
version_color = {
    version: color_cycle[i % len(color_cycle)]
    for i, version in enumerate(unique_versions)
}


GENE_context = project_dict_full[project][case].base_pyro.norms.context

# --- GENE: converged value + uncertainty per gamma_exb (time-resolved data) ---
heat = project_dict_full[project][case].gk_output["heat"].sum(dim="species").sum(dim="field")
time_dim = "time" if "time" in heat.dims else [d for d in heat.dims if d != "gamma_exb"][0]

GENE_exb, GENE_mean, GENE_err = [], [], []
for i, g in enumerate(heat["gamma_exb"].values):
    trace = heat.isel(gamma_exb=i)
    trace_si = xr.DataArray(
        np.asarray(trace.data.to("MW/m^2", GENE_context)),
        coords={time_dim: trace[time_dim].values}, dims=[time_dim])
    t = trace_si[time_dim].values
    t0 = t[0] + t_start_frac * (t[-1] - t[0])
    res = converged_flux(trace_si, time_dim=time_dim)
    GENE_exb.append(float(g)); GENE_mean.append(res["mean"]); GENE_err.append(res["sem"])

GENE_exb = np.asarray(GENE_exb)
GENE_mean = np.asarray(GENE_mean)
GENE_err = np.asarray(GENE_err)

mask = GENE_mean > 0
plt.errorbar(GENE_exb[mask], GENE_mean[mask], yerr=GENE_err[mask],
             label="GENE", color="black", marker="o", capsize=3)

# --- TGLF (unchanged) ---

for tglf in tglf_versions_to_plot:
    for sat_rule in tglf_sat_rules_to_plot:
        for grid_model in tglf_grid_models_to_plot:
            print(f"Plotting {tglf} {sat_rule} grid model {grid_model}")
            try:
                tglf_heat = (
                    tglf_project_dict[project][case][tglf][sat_rule][grid_model]
                    .gk_output["heat"].sum(dim="species").sum(dim="field")
                    .data.to("MW/m^2", GENE_context)
                )
                tglf_exb = (
                    tglf_project_dict[project][case][tglf][sat_rule][grid_model]
                    .gk_output["heat"]["gamma_exb"]
                )
                label = name_dict.get(tglf, tglf)
                plt.plot(
                    tglf_exb, tglf_heat,
                    label=label,
                    color=version_color[label],
                    marker=marker_map.get(sat_rule, "o"),
                    linestyle=style_map.get(sat_rule, "-"),
                )
            except Exception as e:
                print(f"Error plotting {tglf} {sat_rule} grid model {grid_model}: {e}")


#plt.axvline(x=reference_q, color='red',alpha=0.3,linestyle = "--")

plt.title("")
plt.ylabel(r"MW/m$^2$")
plt.xlabel(r"$\gamma_{ExB}$")
plt.grid(alpha=0.3, color='grey')
from matplotlib.lines import Line2D

handles, labels = plt.gca().get_legend_handles_labels()

def handle_color(handle):
    if hasattr(handle, "get_color"):
        return handle.get_color()
    if hasattr(handle, "lines") and len(handle.lines) > 0:
        return handle.lines[0].get_color()
    if isinstance(handle, (list, tuple)) and len(handle) > 0 and hasattr(handle[0], "get_color"):
        return handle[0].get_color()
    return "black"

def legend_marker(label):
    if "sat2" in label:
        return "^"
    if "sat3" in label:
        return "s"
    if "sat1" in label:
        return "o"
    return "o"

dot_handles = [
    Line2D([], [], color=handle_color(h),
           marker=legend_marker(lbl),
           linestyle="none", markersize=8)
    for h, lbl in zip(handles, labels)
]
handles, labels = plt.gca().get_legend_handles_labels()
unique = {}
for h, l in zip(handles, labels):
    if l not in unique:
        unique[l] = h
plt.legend(unique.values(), unique.keys())
plt.yscale("log")
plt.xscale("symlog", linthresh=0.05)
plt.xlim(GENE_exb[0], 1)
path = f"../Plots/{project}/{case}"
os.makedirs(path, exist_ok=True)
plt.savefig(f"{path}/Heat Flux - ExB shear — {case}-with_errors.png", dpi=300)
#plt.savefig(f"{path}/Growth Rate vs q — {case}, ky={ky_actual:.3f}.png", dpi=300)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 27
#      23     for i, version in enumerate(unique_versions)
#      24 }
#      25
#      26
# ---> 27 GENE_context = project_dict_full[project][case].base_pyro.norms.context
#      28
#      29 # --- GENE: converged value + uncertainty per gamma_exb (time-resolved data) ---
#      30 heat = project_dict_full[project][case].gk_output["heat"].sum(dim="species").sum(dim="field")
#
# NameError: name 'project_dict_full' is not defined

# %%
import xarray as xr
from matplotlib import pyplot as plt
from matplotlib.lines import Line2D

# Plot Q scan
project = "nl_exb_scan"
case = "S1"
reference_exb = 3.49
t_start_frac = 0.4   # discard this leading fraction of each GENE trace as transient

tglf_versions_to_plot = ["tglf_default","tglf_v1","tglf_v2"]
tglf_sat_rules_to_plot = ["sat1","sat2","sat3"]
tglf_grid_models_to_plot = [4]

marker_map = {"sat1": "o", "sat2": "s", "sat3": "^"}
style_map  = {"sat1": "-", "sat2": "--", "sat3": ":"}
version_color = {
    "Default": "#d73027",        # red
    "Default_EMWS": "#f46d43",   # orange-red
    "V1": "#fdae61",             # orange
    "V1_EMWS": "#fee08b",        # yellow-orange
    "V2": "#e66101",             # darker orange
}

GENE_context = project_dict_full[project][case].base_pyro.norms.context

# --- GENE: converged value + uncertainty per gamma_exb ---
heat = project_dict_full[project][case].gk_output["heat"].sum(dim="species").sum(dim="field")
time_dim = "time" if "time" in heat.dims else [d for d in heat.dims if d != "gamma_exb"][0]

GENE_exb, GENE_mean, GENE_err = [], [], []
for i, g in enumerate(heat["gamma_exb"].values):
    trace = heat.isel(gamma_exb=i)
    trace_si = xr.DataArray(
        np.asarray(trace.data.to("MW/m^2", GENE_context)),
        coords={time_dim: trace[time_dim].values}, dims=[time_dim])
    res = converged_flux(trace_si, time_dim=time_dim)
    GENE_exb.append(float(g)); GENE_mean.append(res["mean"]); GENE_err.append(res["sem"])

GENE_exb = np.asarray(GENE_exb)
GENE_mean = np.asarray(GENE_mean)
GENE_err = np.asarray(GENE_err)

mask = GENE_mean > 0
plt.errorbar(GENE_exb[mask], GENE_mean[mask], yerr=GENE_err[mask],
             label="GENE", color="black", marker="o", capsize=3)

# --- TGLF ---
for tglf in tglf_versions_to_plot:
    for sat_rule in tglf_sat_rules_to_plot:
        for grid_model in tglf_grid_models_to_plot:
            print(f"Plotting {tglf} {sat_rule} grid model {grid_model}")
            try:
                tglf_heat = (
                    tglf_project_dict[project][case][tglf][sat_rule][grid_model]
                    .gk_output["heat"].sum(dim="species").sum(dim="field")
                    .data.to("MW/m^2", GENE_context)
                )
                tglf_exb = (
                    tglf_project_dict[project][case][tglf][sat_rule][grid_model]
                    .gk_output["heat"]["gamma_exb"]
                )
                version_label = name_dict.get(tglf, tglf)
                plt.plot(
                    tglf_exb,
                    tglf_heat,
                    label=version_label,
                    color=version_color[version_label],
                    marker=marker_map[sat_rule],
                    linestyle=style_map[sat_rule],
                    alpha=0.9,
                )
            except Exception as e:
                print(f"Error plotting {tglf} {sat_rule} grid model {grid_model}: {e}")

ax = plt.gca()

# unique version legend
handles, labels = ax.get_legend_handles_labels()
unique = {}
for h, l in zip(handles, labels):
    if l not in unique:
        unique[l] = h
version_legend = ax.legend(unique.values(), unique.keys(), title="TGLF version", loc="upper left")

# marker legend for saturation rules
sat_handles = [
    Line2D([], [], color="black", marker=marker_map[sr], linestyle="none", markersize=8)
    for sr in tglf_sat_rules_to_plot
]
sat_labels = [f"{sr}" for sr in tglf_sat_rules_to_plot]
sat_legend = ax.legend(sat_handles, sat_labels, title="Saturation rule", loc="lower left")

ax.add_artist(version_legend)

plt.title("")
plt.ylabel(r"MW/m$^2$")
plt.xlabel(r"$\gamma_{ExB}$")
plt.grid(alpha=0.3, color='grey')
plt.yscale("log")
plt.xscale("symlog", linthresh=0.05)
plt.xlim(GENE_exb[0], 1)

path = f"../Plots/{project}/{case}"
os.makedirs(path, exist_ok=True)
plt.savefig(f"{path}/Heat Flux - ExB shear — {case}-with_errors.png", dpi=300)
# Out:
# /tmp/ipykernel_20163/3343339043.py:35: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   np.asarray(trace.data.to("MW/m^2", GENE_context)),
# /tmp/ipykernel_20163/3343339043.py:35: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   np.asarray(trace.data.to("MW/m^2", GENE_context)),
# /tmp/ipykernel_20163/3343339043.py:35: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   np.asarray(trace.data.to("MW/m^2", GENE_context)),
# /tmp/ipykernel_20163/3343339043.py:35: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   np.asarray(trace.data.to("MW/m^2", GENE_context)),
# /tmp/ipykernel_20163/3343339043.py:35: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   np.asarray(trace.data.to("MW/m^2", GENE_context)),
# /tmp/ipykernel_20163/3343339043.py:35: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   np.asarray(trace.data.to("MW/m^2", GENE_context)),
# /tmp/ipykernel_20163/3343339043.py:35: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   np.asarray(trace.data.to("MW/m^2", GENE_context)),
# /tmp/ipykernel_20163/3343339043.py:35: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   np.asarray(trace.data.to("MW/m^2", GENE_context)),
# /home/Felix/Documents/Physics_Work/Project_Codes/EPS_2026_Analysis/.venv/lib/python3.14/site-packages/matplotlib/cbook.py:1355: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   return np.asarray(x, float)
# /home/Felix/Documents/Physics_Work/Project_Codes/EPS_2026_Analysis/.venv/lib/python3.14/site-packages/matplotlib/cbook.py:1355: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   return np.asarray(x, float)
# /home/Felix/Documents/Physics_Work/Project_Codes/EPS_2026_Analysis/.venv/lib/python3.14/site-packages/matplotlib/cbook.py:1355: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   return np.asarray(x, float)
# Plotting tglf_default sat1 grid model 4
# Plotting tglf_default sat2 grid model 4
# Plotting tglf_default sat3 grid model 4
# Plotting tglf_v1 sat1 grid model 4
# Error plotting tglf_v1 sat1 grid model 4: 'tglf_v1'
# Plotting tglf_v1 sat2 grid model 4
# Error plotting tglf_v1 sat2 grid model 4: 'tglf_v1'
# Plotting tglf_v1 sat3 grid model 4
# Error plotting tglf_v1 sat3 grid model 4: 'tglf_v1'
# Plotting tglf_v2 sat1 grid model 4
# Error plotting tglf_v2 sat1 grid model 4: 'tglf_v2'
# Plotting tglf_v2 sat2 grid model 4
# Error plotting tglf_v2 sat2 grid model 4: 'tglf_v2'
# Plotting tglf_v2 sat3 grid model 4
# Error plotting tglf_v2 sat3 grid model 4: 'tglf_v2'

# %%
import xarray as xr
import numpy as np
import matplotlib.colors as mcolors
from matplotlib import pyplot as plt
from matplotlib.lines import Line2D

project = "nl_exb_scan"
case = "S1"
t_start_frac = 0.4

tglf_versions_to_plot  = ["tglf_default", "V5_NM10", "tglf_v5_nm10"]
tglf_sat_rules_to_plot = ["sat3"]

marker_map = {"sat1": "s", "sat2": "o", "sat3": "^"}
style_map  = {"sat1": "-", "sat2": "--", "sat3": ":"}

# Base colour per version — perceptually distinct
version_base_color = {
    "tglf_default": "#1f77b4",  # blue
    "tglf_v5_nb6":      "#d62728",  # red
    #"tglf_v2":      "#2ca02c",  # green
    #"tglf_v3":      "#EE27F5",  # pink
    "tglf_v5_nm10":      "#2ca02c",  # pink
}

# Lightness multipliers per sat rule (same hue, different brightness)
sat_lightness = {"sat1": 1.0, "sat2": 1.0, "sat3": 1.3}

def adjust_lightness(color, factor):
    """Scale the lightness of a colour in HLS space."""
    import colorsys
    r, g, b = mcolors.to_rgb(color)
    h, l, s = colorsys.rgb_to_hls(r, g, b)
    l = max(0.0, min(1.0, l * factor))
    return colorsys.hls_to_rgb(h, l, s)

GENE_context = project_dict_full[project][case].base_pyro.norms.context

# --- GENE ---
heat = project_dict_full[project][case].gk_output["heat"].sum(dim="species").sum(dim="field")
time_dim = "time" if "time" in heat.dims else [d for d in heat.dims if d != "gamma_exb"][0]

GENE_exb, GENE_mean, GENE_err = [], [], []
for i, g in enumerate(heat["gamma_exb"].values):
    trace = heat.isel(gamma_exb=i)
    trace_si = xr.DataArray(
        np.asarray(trace.data.to("MW/m^2", GENE_context)),
        coords={time_dim: trace[time_dim].values}, dims=[time_dim],
    )
    res = converged_flux(trace_si, time_dim=time_dim)
    GENE_exb.append(float(g)); GENE_mean.append(res["mean"]); GENE_err.append(res["sem"])

GENE_exb  = np.asarray(GENE_exb)
GENE_mean = np.asarray(GENE_mean)
GENE_err  = np.asarray(GENE_err)
mask = GENE_mean > 0

fig, ax = plt.subplots()
ax.errorbar(GENE_exb[mask], GENE_mean[mask], yerr=GENE_err[mask],
            label="GENE", color="black", marker="o", capsize=3)

# --- TGLF ---
for tglf in tglf_versions_to_plot:
    base_col = version_base_color[tglf]
    for sat_rule in tglf_sat_rules_to_plot:
        color = adjust_lightness(base_col, sat_lightness[sat_rule])
        try:
            pyroscan = tglf_project_dict[project][case][tglf][sat_rule][4]
            tglf_heat = np.asarray(
                pyroscan.gk_output["heat"].sum(dim="species").sum(dim="field")
                .data.to("MW/m^2", GENE_context)
            )
            tglf_exb = pyroscan.gk_output["heat"]["gamma_exb"].values
            version_label = name_dict.get(tglf, tglf)
            ax.plot(
                tglf_exb, tglf_heat,
                color=color,
                marker=marker_map[sat_rule],
                linestyle=style_map[sat_rule],
                alpha=0.9,
                label=f"{version_label}_{sat_rule}",  # full label for internal tracking
            )
        except Exception as e:
            print(f"Error plotting {tglf} {sat_rule}: {e}")

# --- Legends ---
# Version legend: one solid line per version in its base colour
version_handles = [
    Line2D([], [], color=version_base_color[v], linewidth=2,
           label=name_dict.get(v, v))
    for v in tglf_versions_to_plot
]
version_handles.insert(0, Line2D([], [], color="black", linewidth=2, label="GENE"))
version_legend = ax.legend(handles=version_handles, title="Version", loc="upper left")

# Sat rule legend: marker + linestyle in neutral grey
sat_handles = [
    Line2D([], [], color="black", marker=marker_map[sr], linestyle=style_map[sr],
           markersize=7, label=sr)
    for sr in tglf_sat_rules_to_plot
]
ax.legend(handles=sat_handles, title="Sat. rule", loc="lower left")
ax.add_artist(version_legend)

ax.set_ylabel(r"MW/m$^2$")
ax.set_xlabel(r"$\gamma_{ExB}$")
ax.set_yscale("log")
ax.set_xscale("symlog", linthresh=0.1)
ax.set_xlim(GENE_exb[0], 1)
ax.grid(alpha=0.3, color="black")
from matplotlib.ticker import AutoMinorLocator
ax.xaxis.set_minor_locator(AutoMinorLocator())

ax.axvline(x=reference_exb, color='red', alpha=0.5, linestyle='--', label=r'$\gamma_{ExB}$ ref')
# or shade the linear region
ax.axvspan(0, 0.1, alpha=0.05, color='blue', label='linear regime')
plt.title(f"Heat Flux vs ExB shear — STEP-EC-HD")

path = f"../Plots/{project}/{case}"
os.makedirs(path, exist_ok=True)
fig.savefig(f"{path}/Heat Flux - ExB shear — {case}-with_errors.png", dpi=300)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 37
#      33     h, l, s = colorsys.rgb_to_hls(r, g, b)
#      34     l = max(0.0, min(1.0, l * factor))
#      35     return colorsys.hls_to_rgb(h, l, s)
#      36
# ---> 37 GENE_context = project_dict_full[project][case].base_pyro.norms.context
#      38
#      39 # --- GENE ---
#      40 heat = project_dict_full[project][case].gk_output["heat"].sum(dim="species").sum(dim="field")
#
# NameError: name 'project_dict_full' is not defined

# %%
ax = (
    tglf_project_dict["nl_exb_scan"]["S1"]["tglf_v3"]["sat1"][1]
    .gk_output["heat"]
    .sum(dim="species")
    .sum(dim="field")
    .plot()
)
ax.set_yscale("log")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 8
#       4     .sum(dim="species")
#       5     .sum(dim="field")
#       6     .plot()
#       7 )
# ----> 8 ax.set_yscale("log")
#
# AttributeError: 'list' object has no attribute 'set_yscale'

# %%
import matplotlib.pyplot as plt

da = (
    tglf_project_dict["nl_exb_scan"]["S1"]["tglf_v3"]["sat1"][1]
    .gk_output["heat"]
    .sum(dim="species")
    .sum(dim="field")
)

da.plot()

ax = plt.gca()
ax.set_yscale("log")

plt.show()

# %%
print(tglf_project_dict[project][case].keys())
print(tglf_project_dict[project][case]["tglf_default"].keys())
print(tglf_project_dict[project][case]["tglf_default"]["sat3"].keys())  # does "sat3" even exist?
# Out:
# dict_keys(['tglf_default', 'tglf_default_negwm', 'tglf_v1', 'tglf_v1_negwm', 'tglf_v2', 'tglf_v3'])
# dict_keys(['sat1', 'sat2', 'sat3'])
# dict_keys([1, 4])

# %%
import xarray as xr
from matplotlib import pyplot as plt

def plot_convergence(scan_dict, project, case, t_frac=0.2,
                     ncols=4, to_units="MW/m^2", n_blocks=None, zoom=False):

    """One panel per gamma_exb: time trace + averaging window + block boxes.
    Self-contained: replicates the converged_flux math so nothing can drift."""
    pyro = scan_dict[project][case]
    ctx = pyro.base_pyro.norms.context
    heat = pyro.gk_output["heat"].sum(dim="species").sum(dim="field")
    tdim = "time" if "time" in heat.dims else [d for d in heat.dims if d != "gamma_exb"][0]
    gammas = heat["gamma_exb"].values

    n = len(gammas)
    ncols = min(ncols, n)
    nrows = int(np.ceil(n / ncols))
    fig, axes = plt.subplots(nrows, ncols, figsize=(4.2 * ncols, 3 * nrows),
                             squeeze=False)

    for k, (g, ax) in enumerate(zip(gammas, axes.flat)):
        tr = heat.isel(gamma_exb=k)
        da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
                          coords={tdim: tr[tdim].values}, dims=[tdim])
        da = da.where((da != 0) & da.notnull(), drop=True)     # strip padding

        # --- window ---
        time = da[tdim]
        t_start = time.max().item() - t_frac * (time.max().item() - time.min().item())
        q = da.where(da[tdim] >= t_start, drop=True)
        t = q[tdim].values
        y = np.asarray(q.values, dtype=float)
        N = y.size
        mean = y.mean()

        # --- autocorrelation time (for N_eff) ---
        yc = y - mean
        acf = np.correlate(yc, yc, mode="full")[N - 1:]
        acf /= acf[0]
        first_neg = np.argmax(acf < 0)
        cutoff = first_neg if first_neg > 0 else N
        tau_int = 1.0 + 2.0 * acf[1:cutoff].sum()
        N_eff = N / max(tau_int, 1.0)

        # --- blocks ---
        nb = n_blocks if n_blocks is not None else max(4, int(N / (5 * max(tau_int, 1.0))))
        nb = min(nb, N)
        edges = np.array_split(np.arange(N), nb)
        block_means = np.array([y[idx].mean() for idx in edges])
        sem = block_means.std(ddof=1) / np.sqrt(len(block_means))
        blocks = [(t[idx[0]], t[idx[-1]], y[idx].mean()) for idx in edges]

        # --- draw ---
        tt, yy = da[tdim].values, da.values
        ax.plot(tt, yy, color="0.6", lw=0.8)                   # full Q(t)
        for j, (tl, tr2, bm) in enumerate(blocks):             # block boxes
            ax.axvspan(tl, tr2, color="tab:blue", alpha=0.10 if j % 2 else 0.04)
            ax.hlines(bm, tl, tr2, color="tab:red", lw=1.6, zorder=5)
        t_end = tt[-1]
        ax.hlines(mean, t_start, t_end, color="k", lw=1.4, zorder=6)
        ax.fill_between([t_start, t_end], mean - sem, mean + sem,
                        color="k", alpha=0.15, zorder=4)
        ax.axvline(t_start, color="k", ls="--", lw=0.8)
        if zoom:
            ax.set_xlim(t_start, t_end)
            pad = 0.05 * (y.max() - y.min() or 1.0)
            ax.set_ylim(y.min() - pad, y.max() + pad)
        ax.set_title(r"$\gamma_{ExB}=%.3g$: Q=%.3g$\pm$%.2g (N$_{block}$=%.0f)"
                     % (g, mean, sem, nb), fontsize=8)
        ax.set_xlabel("time"); ax.set_ylabel(to_units)

    for ax in axes.flat[n:]:
        ax.axis("off")
    fig.suptitle(f"{project} / {case}  (t_frac={t_frac})", y=1.0)
    fig.tight_layout()
    return fig


project = "nl_exb_scan"
for case in project_dict_full[project]:
    plot_convergence(project_dict_full, project, case, t_frac=0.2)
plt.show()
# Out:
# /tmp/ipykernel_163950/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_163950/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_163950/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_163950/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_163950/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_163950/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_163950/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_163950/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_163950/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_163950/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_163950/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_163950/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_163950/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_163950/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_163950/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_163950/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_163950/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_163950/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),

# %%
project = "nl_exb_scan"
for case in project_dict_full[project]:
    plot_convergence(project_dict_full, project, case, t_frac=0.2)              # full trace
    plot_convergence(project_dict_full, project, case, t_frac=0.2, zoom=True)   # window only
plt.show()
# Out:
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
# /tmp/ipykernel_123756/355312601.py:23: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   da = xr.DataArray(np.asarray(tr.data.to(to_units, ctx)),
